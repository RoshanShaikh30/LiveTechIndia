# %%
# %pip install nltk scikit-learn numpy
# Out:
# Requirement already satisfied: nltk in c:\users\roshan\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\roshan\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy in c:\users\roshan\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: click in c:\users\roshan\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\roshan\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\roshan\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\roshan\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\roshan\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\roshan\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import random
import string
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Roshan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
knowledge_base = {
    "what is nlp":
        "NLP stands for Natural Language Processing. It helps computers understand human language.",

    "what is machine learning":
        "Machine Learning is a branch of AI that enables systems to learn from data.",

    "what is deep learning":
        "Deep Learning is a subset of Machine Learning that uses neural networks.",

    "what is artificial intelligence":
        "Artificial Intelligence is the simulation of human intelligence by machines.",

    "what is python":
        "Python is a popular programming language used in AI, Data Science and Web Development.",

    "what is chatbot":
        "A chatbot is a software application that interacts with users through text or voice.",

    "what is data science":
        "Data Science combines statistics, programming and domain knowledge to extract insights from data.",

    "what is tensorflow":
        "TensorFlow is an open-source deep learning framework developed by Google.",

    "what is neural network":
        "A neural network is a computational model inspired by the human brain."
}

# %%
def preprocess(text):

    text = text.lower()

    text = ''.join(
        char for char in text
        if char not in string.punctuation
    )

    return text

# ------------------------------------------
# GREETING FUNCTION
# ------------------------------------------

greetings = ["hi", "hello", "hey", "good morning", "good evening"]

greeting_responses = [
    "Hello!",
    "Hi there!",
    "Hey!",
    "Nice to meet you!"
    "hii"
    "Hii"
]

def greeting(user_input):

    words = word_tokenize(user_input.lower())

    for word in words:
        if word in greetings:
            return random.choice(greeting_responses)

    return None

# ------------------------------------------
# RESPONSE FUNCTION
# ------------------------------------------

def get_response(user_input):

    user_input = preprocess(user_input)

    questions = list(knowledge_base.keys())

    vectorizer = TfidfVectorizer()

    tfidf_matrix = vectorizer.fit_transform(
        questions + [user_input]
    )

    similarity_scores = cosine_similarity(
        tfidf_matrix[-1],
        tfidf_matrix[:-1]
    )

    best_match_index = similarity_scores.argmax()

    confidence = similarity_scores[0][best_match_index]

    if confidence > 0.30:
        best_question = questions[best_match_index]
        return knowledge_base[best_question]

    return "Sorry, I don't understand that question."

# ------------------------------------------
# CHATBOT
# ------------------------------------------

print("=" * 50)
print("      NLP CHATBOT")
print("=" * 50)
print("Type 'bye' to exit")
print()

while True:

    user_input = input("You: ")

    if user_input.lower() == "bye":
        print("Bot: Goodbye! Have a nice day.")
        break

    greet = greeting(user_input)

    if greet:
        print("Bot:", greet)
        continue

    response = get_response(user_input)

    print("Bot:", response)

print("\nChatbot Closed Successfully.")
# Out:
# ==================================================
#       NLP CHATBOT
# ==================================================
# Type 'bye' to exit
# You:  c-
# Bot: Sorry, I don't understand that question.
# You:  What is your name
# Bot: Sorry, I don't understand that question.
# You:  hello
# Bot: Nice to meet you!hiiHii
# You:  what is data science
# Bot: Data Science combines statistics, programming and domain knowledge to extract insights from data.
# You:  bye
# Bot: Goodbye! Have a nice day.
#
# Chatbot Closed Successfully.
