# %%
# %pip install opencv-python
# %pip install numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\roshan\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\roshan\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\roshan\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread("bird.jpeg")



plt.imshow(img)
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title('Gray Image')
plt.axis("off")
plt.show()

# %%
resized = cv2.resize(img,(300,300))
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.title("Resized Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %%
crop = img[50:100, 15:100]
plt.imshow(crop)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(284.5), np.float64(49.5), np.float64(-0.5))

# %%
img_copy = img.copy()
cv2.rectangle(img_copy, (50,50),(200,200),(0,255,0),2)
cv2.circle(img_copy, (150,150),50,(255,0,0),-1)
plt.imshow(cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB))
plt.title("Shapes")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1065.5), np.float64(-0.5))

# %%
blur = cv2.GaussianBlur(img,(51,51),0)
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(blur,cv2.COLOR_BGR2RGB))
plt.title('Blurred')
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray,(7,7),0)
edges= cv2.Canny(blur, 30,100)
plt.imshow(edges, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1065.5), np.float64(-0.5))
